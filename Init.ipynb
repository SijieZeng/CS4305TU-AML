# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting absl-py==0.14.0
#   Downloading absl_py-0.14.0-py3-none-any.whl (131 kB)
# Collecting aggdraw==1.3.12
#   Downloading aggdraw-1.3.12-cp37-cp37m-manylinux2010_x86_64.whl (795 kB)
# Requirement already satisfied: astunparse==1.6.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (1.6.3)
# Collecting biogeme==3.2.8
#   Downloading biogeme-3.2.8.tar.gz (1.5 MB)
# Collecting cachetools==4.2.2
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: certifi==2021.5.30 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 6)) (2021.5.30)
# Requirement already satisfied: charset-normalizer==2.0.6 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 7)) (2.0.6)
# Collecting clang==5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Requirement already satisfied: cycler==0.10.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 9)) (0.10.0)
# Collecting Cython==0.29.24
#   Downloading Cython-0.29.24-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# Requirement already satisfied: flatbuffers==1.12 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 11)) (1.12)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-auth==1.35.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 13)) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 15)) (0.2.0)
# Collecting grpcio==1.41.0
#   Downloading grpcio-1.41.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
# Collecting h5py==3.1.0
#   Downloading h5py-3.1.0-cp37-cp37m-manylinux1_x86_64.whl (4.0 MB)
# Requirement already satisfied: idna==3.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 18)) (3.2)
# Requirement already satisfied: joblib==1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 19)) (1.0.1)
# Requirement already satisfied: keras==2.6.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 20)) (2.6.0)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 21)) (1.1.2)
# Requirement already satisfied: kiwisolver==1.3.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 22)) (1.3.2)
# Requirement already satisfied: Markdown==3.3.4 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 23)) (3.3.4)
# Requirement already satisfied: matplotlib==3.4.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 24)) (3.4.3)
# Requirement already satisfied: numpy==1.19.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 25)) (1.19.5)
# Requirement already satisfied: oauthlib==3.1.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 26)) (3.1.1)
# Requirement already satisfied: opt-einsum==3.3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 27)) (3.3.0)
# Collecting pandas==1.3.3
#   Downloading pandas-1.3.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
# Requirement already satisfied: Pillow==8.3.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 29)) (8.3.2)
# Collecting protobuf==3.18.0
#   Downloading protobuf-3.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: pyasn1==0.4.8 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 31)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 32)) (0.2.8)
# Requirement already satisfied: pyparsing==2.4.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 33)) (2.4.7)
# Requirement already satisfied: python-dateutil==2.8.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 34)) (2.8.2)
# Collecting pytz==2021.1
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: requests==2.26.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 36)) (2.26.0)
# Requirement already satisfied: requests-oauthlib==1.3.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 37)) (1.3.0)
# Requirement already satisfied: rsa==4.7.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 38)) (4.7.2)
# Requirement already satisfied: scikit-learn==1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 39)) (1.0)
# Requirement already satisfied: scipy==1.7.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 40)) (1.7.1)
# Requirement already satisfied: seaborn==0.11.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 41)) (0.11.2)
# Collecting six==1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: tensorboard==2.6.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 44)) (2.6.0)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 45)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 46)) (1.8.0)
# Collecting tensorflow==2.6.0
#   Downloading tensorflow-2.6.0-cp37-cp37m-manylinux2010_x86_64.whl (458.3 MB)
# Collecting tensorflow-estimator==2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: termcolor==1.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 49)) (1.1.0)
# Collecting threadpoolctl==2.2.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm==4.62.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 51)) (4.62.3)
# Collecting typing-extensions==3.7.4.3
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting Unidecode==1.3.2
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
# Requirement already satisfied: urllib3==1.26.7 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 54)) (1.26.7)
# Collecting visualkeras==0.0.2
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Collecting Werkzeug==2.0.1
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Requirement already satisfied: wrapt==1.12.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 57)) (1.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /root/venv/lib/python3.7/site-packages (from astunparse==1.6.3->-r ./requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: setuptools>=40.3.0 in /root/venv/lib/python3.7/site-packages (from google-auth==1.35.0->-r ./requirements.txt (line 13)) (58.1.0)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from Markdown==3.3.4->-r ./requirements.txt (line 23)) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->Markdown==3.3.4->-r ./requirements.txt (line 23)) (3.6.0)
# Building wheels for collected packages: biogeme, clang, sklearn
#   Building wheel for biogeme (setup.py): started
#   Building wheel for biogeme (setup.py): still running...
#   Building wheel for biogeme (setup.py): finished with status 'done'
#   Created wheel for biogeme: filename=biogeme-3.2.8-cp37-cp37m-linux_x86_64.whl size=653900 sha256=474dd8ee4716667754f546022c471ca111593f2ad1534709373dfed2c8d30cb5
#   Stored in directory: /root/.cache/pip/wheels/d4/52/61/de6c73d2bc17603c60e754e260bccb7d4da2503e97015ebd49
#   Building wheel for clang (setup.py): started
#   Building wheel for clang (setup.py): finished with status 'done'
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30692 sha256=4c6e4e6b721cacbb8e4a2a9a86790cd26d96b08dd6b46e2cceccff8328e55cdc
#   Stored in directory: /root/.cache/pip/wheels/98/91/04/971b4c587cf47ae952b108949b46926f426c02832d120a082a
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=66c3cc40e1586866c6bfe4286069f9d3d76212c5f5b54aef2e80e7c5cadaae81
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built biogeme clang sklearn
# Installing collected packages: typing-extensions, six, cachetools, Werkzeug, threadpoolctl, pytz, protobuf, grpcio, cached-property, absl-py, Unidecode, tensorflow-estimator, pandas, h5py, gast, Cython, clang, aggdraw, visualkeras, tensorflow, sklearn, biogeme
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Not uninstalling typing-extensions at /shared-libs/python3.7/py-core/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'typing-extensions'. No files were found to uninstall.
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Not uninstalling six at /shared-libs/python3.7/py-core/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'six'. No files were found to uninstall.
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.4
#     Not uninstalling cachetools at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'cachetools'. No files were found to uninstall.
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.2
#     Not uninstalling werkzeug at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'Werkzeug'. No files were found to uninstall.
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.0.0
#     Not uninstalling threadpoolctl at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'threadpoolctl'. No files were found to uninstall.
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.3
#     Not uninstalling pytz at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'pytz'. No files were found to uninstall.
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Not uninstalling protobuf at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'protobuf'. No files were found to uninstall.
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.32.0
#     Not uninstalling grpcio at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'grpcio'. No files were found to uninstall.
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.14.1
#     Not uninstalling absl-py at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'absl-py'. No files were found to uninstall.
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.4.0
#     Not uninstalling tensorflow-estimator at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'tensorflow-estimator'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Not uninstalling h5py at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'h5py'. No files were found to uninstall.
#   Attempting uninstall: gast
#     Found existing installation: gast 0.3.3
#     Not uninstalling gast at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'gast'. No files were found to uninstall.
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.4.1
#     Not uninstalling tensorflow at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'tensorflow'. No files were found to uninstall.
# Successfully installed Cython-0.29.24 Unidecode-1.3.2 Werkzeug-2.0.1 absl-py-0.14.0 aggdraw-1.3.12 biogeme-3.2.8 cached-property-1.5.2 cachetools-4.2.2 clang-5.0 gast-0.4.0 grpcio-1.41.0 h5py-3.1.0 pandas-1.3.3 protobuf-3.18.0 pytz-2021.1 six-1.15.0 sklearn-0.0 tensorflow-2.6.0 tensorflow-estimator-2.6.0 threadpoolctl-2.2.0 typing-extensions-3.7.4.3 visualkeras-0.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 1.31.3 requires protobuf<3.18.0,>=3.12.0, but you have protobuf 3.18.0 which is incompatible.
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8ad46a34-f541-4527-b60e-9406e1d2b4c0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
